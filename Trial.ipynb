# %%
a = 4
b = 9
c = a + b
d = c - a
print(d)
# Out:
# 9

# %% [markdown]
# **Маша**
# # ttt

# %%
a = 'http://jupyter.org'
print(a)
# Out:
# http://jupyter.org

# %% [markdown]
# ![title](7.jpg)

# %%
import os
os.getcwd()
# Out:
# '/Users/air/My'

# %%
os.getcwd()
# Out:
# '/Users/air/My'

# %%
a = 'hello world'
print(a) # имей совесть
'''
кому 
говорю
'''
print (a)
# Out:
# hello world
# hello world

# %%
x = 2
type(x)
# Out:
# int

# %%
2 + 2
# Out:
# 4

# %%
print(2+2)
# Out:
# 4

# %%
print(5 / 2)
# Out:
# 2.5

# %%
type(2.5)
# Out:
# float

# %%
7 // 9
# Out:
# 0

# %%
7 // 6
# Out:
# 1

# %%
2.5 // 3.5
# Out:
# 0.0

# %%
2.03 // 6
# Out:
# 0.0

# %%
2.004 / 2.003
# Out:
# 1.000499251123315

# %%
4 % 3
# Out:
# 1

# %%
4 / 3
# Out:
# 1.3333333333333333

# %%
print(2 ** 3)
# Out:
# 8

# %%
a = 7
b = 2
print(a ** b)
# Out:
# 49

# %%
b ** a
# Out:
# 128

# %%
4
# Out:
# 4

# %%
a = "2"

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
print(a + a)
print(int(a) + int(a))
# Out:
# 22
# 4

# %%
print(type(a + a))
# Out:
# <class 'str'>

# %%
print(type(int(a) + int(a)))
# Out:
# <class 'int'>

# %%
a = 179

# %%
b = 1
c = 7
d = 9 
print(b + c + d)
# Out:
# 17
